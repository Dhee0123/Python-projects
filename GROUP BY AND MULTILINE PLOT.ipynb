# %%
# import packages

import pandas as pd
import numpy as np

# reading csv file

x = pd.read_csv('insurance_data_with_day.csv')

# print dataset of csv file using onlu variable name or using print()

x
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 0             1          19   39    male  23.2             91      Yes
# 1             2           8   24    male  30.1             87       No
# 2             3          11   27    male  33.3             82      Yes
# 3             4           5   37    male  33.7             80       No
# 4             5          21   30    male  34.1            100       No
# ...         ...         ...  ...     ...   ...            ...      ...
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 0            0     No  southeast   1121.87
# ...

# %%
x.tail()
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 1335         0    Yes  northwest  55135.40
# 1336         1    Yes  northeast  58571.07
# 1337         3    Yes  northwest  60021.40
# 1338         0    Yes  southeast  62592.87
# 1339         0    Yes  southeast  63770.43

# %%
# use groupby method to group the dataframe by specific coloumn

# form a gender group using group by function

gender_group = x.groupby(['gender'])
gender_group

for a,b in gender_group:
    print(a)
    print(b.head(1))

# %%
df_female = gender_group.get_group('female')
df_female.head(1)
# Out:
#     patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 24         25          18   50  female  20.8             85      Yes
#
#     children smoker     region    claim
# 24         0     No  southeast  1607.51

# %%
#functions on groupby object

print(gender_group.min())
# Out:
#         patientid  dayofmonth  age   bmi  bloodpressure diabetic  children  \
# gender
# female         25           1   25  16.8             80       No         0
# male            1           1   18  16.0             80       No         0
#
#        smoker     region    claim
# gender
# female     No  northeast  1607.51
# male       No  northeast  1121.87

# %%
print(gender_group.max())
# Out:
#         patientid  dayofmonth  age   bmi  bloodpressure diabetic  children  \
# gender
# female       1340          30   60  48.1            140      Yes         5
# male         1339          30   50  53.1            140      Yes         5
#
#        smoker     region     claim
# gender
# female    Yes  southwest  63770.43
# male      Yes  southwest  62592.87

# %%
print(gender_group.mean())
# Out:
#          patientid  dayofmonth        age        bmi  bloodpressure  children  \
# gender
# female  667.667674   15.640483  42.483384  30.379758      94.013595  1.074018
# male    673.265487   14.687316  33.747788  30.951327      94.297935  1.112094
#
#                claim
# gender
# female  12569.578897
# male    13919.790457

# %%
x.groupby(by = 'region')['claim'].sum()
# Out:
# region
# northeast    3901369.33
# northwest    4073558.87
# southeast    5784925.54
# southwest    3998825.42
# Name: claim, dtype: float64

# %%
x.groupby(by = 'region')['claim'].mean()
# Out:
# region
# northeast    16889.044719
# northwest    11672.088453
# southeast    13058.522664
# southwest    12614.591230
# Name: claim, dtype: float64

# %%
x.groupby(by = ['region','gender',])['gender'].count()
# Out:
# region     gender
# northeast  female    112
#            male      119
# northwest  female    164
#            male      185
# southeast  female    224
#            male      219
# southwest  female    162
#            male      155
# Name: gender, dtype: int64

# %%
# simple line plot

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [2, 4, 6, 5, 6, 8]
z = [5, 3, 7, 8, 9, 6]

fig, ax = plt.subplots()

ax.plot(x, y,color ='b',marker='*')
ax.plot(x, z,color ='r',marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

line_1 = np.random.randint(low = 0, high = 50, size = 50)
line_2 = np.random.randint(low = -15, high = 100, size = 50)

fig, ax = plt.subplots()

ax.plot(line_1, color = 'green', label = 'Line 1')
ax.plot(line_2, color = 'red', label = 'Line 2')
ax.legend(loc = 'upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')
ax.legend(loc = 'upper right')


plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')

plt.xlim([25, 50])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')

plt.xlim([25, 50])
plt.ylim([0,1])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')

plt.xlim([25, 50])
plt.ylim([0,1])
plt.xticks([0,25,50])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')

plt.xlim([25, 50])
plt.ylim([0,1])
plt.xticks([0,25,50])
plt.yticks([-1,0,1])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-darkgrid')

# %%
x = pd.read_csv('insurance_data_with_day.csv')

a = x.groupby('dayofmonth')

b = a['dayofmonth'].mean()

# %%
plt.plot(b,a['age'].mean(),color='limegreen',marker='*',label='age')
plt.plot(b,a['bmi'].mean(),color='crimson',marker='*',label='bmi')
plt.plot(b,a['bloodpressure'].mean(),color='red',marker='*',label='bloodpressure')

plt.title('multi line plot')
plt.xlabel('days')
plt.ylabel('measures')
plt.legend(loc = 'center right')
plt.show()

# %%
plt.style.use()
